# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore')
matplotlib.rcParams['figure.figsize'] = (10, 10)

# %%
data = pd.read_csv("owid-covid-data.csv", header=[0], parse_dates=['date'])

# %%
data.head()
# Out:
#   iso_code      continent location       date  total_cases  new_cases  \
# 0      ABW  North America    Aruba 2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba 2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba 2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba 2020-03-21          NaN        NaN
# 4      ABW  North America    Aruba 2020-03-22          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           0.0         0.0                  0.0  ...
# 3               0.286           NaN         NaN                  0.0  ...
# 4               0.286           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
data
# Out:
#       iso_code      continent       location       date  total_cases  \
# 0          ABW  North America          Aruba 2020-03-13          2.0
# 1          ABW  North America          Aruba 2020-03-19          NaN
# 2          ABW  North America          Aruba 2020-03-20          4.0
# 3          ABW  North America          Aruba 2020-03-21          NaN
# 4          ABW  North America          Aruba 2020-03-22          NaN
# ...        ...            ...            ...        ...          ...
# 50296      NaN            NaN  International 2020-10-11        696.0
# 50297      NaN            NaN  International 2020-10-12        696.0
# 50298      NaN            NaN  International 2020-10-13        696.0
# 50299      NaN            NaN  International 2020-10-14        696.0
# 50300      NaN            NaN  International 2020-10-15        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            2.0                 NaN           0.0         0.0
# ...

# %%
#Finding the continent asia
data[data['continent'] == "Asia"]
# Out:
#       iso_code continent     location       date  total_cases  new_cases  \
# 212        AFG      Asia  Afghanistan 2019-12-31          0.0        0.0
# 213        AFG      Asia  Afghanistan 2020-01-01          0.0        0.0
# 214        AFG      Asia  Afghanistan 2020-01-02          0.0        0.0
# 215        AFG      Asia  Afghanistan 2020-01-03          0.0        0.0
# 216        AFG      Asia  Afghanistan 2020-01-04          0.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 49044      YEM      Asia        Yemen 2020-10-11       2055.0        1.0
# 49045      YEM      Asia        Yemen 2020-10-12       2055.0        0.0
# 49046      YEM      Asia        Yemen 2020-10-13       2056.0        1.0
# 49047      YEM      Asia        Yemen 2020-10-14       2056.0        0.0
# 49048      YEM      Asia        Yemen 2020-10-15       2057.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
#Counting the null values
data.isnull().sum()
# Out:
# iso_code                             290
# continent                            580
# location                               0
# date                                   0
# total_cases                          636
# new_cases                            862
# new_cases_smoothed                  1644
# total_deaths                         636
# new_deaths                           862
# new_deaths_smoothed                 1644
# total_cases_per_million              926
# new_cases_per_million                926
# new_cases_smoothed_per_million      1709
# total_deaths_per_million             926
# new_deaths_per_million               926
# new_deaths_smoothed_per_million     1709
# new_tests                          32016
# total_tests                        31590
# total_tests_per_thousand           31590
# new_tests_per_thousand             32016
# new_tests_smoothed                 29607
# new_tests_smoothed_per_thousand    29607
# tests_per_case                     31233
# ...

# %%
#Counting the % of null values
data.isnull().sum()/(len(data))
# Out:
# iso_code                           0.005765
# continent                          0.011531
# location                           0.000000
# date                               0.000000
# total_cases                        0.012644
# new_cases                          0.017137
# new_cases_smoothed                 0.032683
# total_deaths                       0.012644
# new_deaths                         0.017137
# new_deaths_smoothed                0.032683
# total_cases_per_million            0.018409
# new_cases_per_million              0.018409
# new_cases_smoothed_per_million     0.033975
# total_deaths_per_million           0.018409
# new_deaths_per_million             0.018409
# new_deaths_smoothed_per_million    0.033975
# new_tests                          0.636488
# total_tests                        0.628019
# total_tests_per_thousand           0.628019
# new_tests_per_thousand             0.636488
# new_tests_smoothed                 0.588597
# ...

# %%
#Visualizing the null values, (yellow lines shows the null values)
plt.figure(figsize = (10,7))
import seaborn as sns
sns.heatmap(data.isnull(), annot=False, yticklabels=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50301 entries, 0 to 50300
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         50011 non-null  object
#  1   continent                        49721 non-null  object
#  2   location                         50301 non-null  object
#  3   date                             50301 non-null  datetime64[ns]
#  4   total_cases                      49665 non-null  float64
#  5   new_cases                        49439 non-null  float64
#  6   new_cases_smoothed               48657 non-null  float64
#  7   total_deaths                     49665 non-null  float64
#  8   new_deaths                       49439 non-null  float64
#  9   new_deaths_smoothed              48657 non-null  float64
#  10  total_cases_per_million          49375 non-null  float64
# ...

# %%
data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  4.966500e+04   49439.000000        48657.000000  4.966500e+04
# mean   1.195808e+05    1560.718845         1545.047819  4.528506e+03
# std    1.235767e+06   14074.821975        13848.545713  4.193538e+04
# min    0.000000e+00   -8261.000000         -552.000000  0.000000e+00
# 25%    7.300000e+01       0.000000            0.714000  1.000000e+00
# 50%    1.201000e+03      11.000000           16.571000  2.400000e+01
# 75%    1.353500e+04     183.000000          189.571000  2.800000e+02
# max    3.858123e+07  388539.000000       336660.571000  1.093140e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  49439.000000         48657.000000             49375.000000
# mean      44.221161            44.305880              2208.635648
# std      370.399641           360.225437              4566.847850
# min    -1918.000000          -232.143000                 0.000000
# ...

# %%
#splitting the nepal rows
nepal = data[data['location'] == 'Nepal']

# %%
#Counting the data of Nepal
len(nepal)
# Out:
# 290

# %%
nepal
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 34882      NPL      Asia    Nepal 2019-12-31          0.0        0.0
# 34883      NPL      Asia    Nepal 2020-01-01          0.0        0.0
# 34884      NPL      Asia    Nepal 2020-01-02          0.0        0.0
# 34885      NPL      Asia    Nepal 2020-01-03          0.0        0.0
# 34886      NPL      Asia    Nepal 2020-01-04          0.0        0.0
# ...        ...       ...      ...        ...          ...        ...
# 35167      NPL      Asia    Nepal 2020-10-11     105684.0     5008.0
# 35168      NPL      Asia    Nepal 2020-10-12     107755.0     2071.0
# 35169      NPL      Asia    Nepal 2020-10-13     111802.0     4047.0
# 35170      NPL      Asia    Nepal 2020-10-14     115358.0     3556.0
# 35171      NPL      Asia    Nepal 2020-10-15     117996.0     2638.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
#Data for Asia
asia = data[data['continent'] == 'Asia']

# %%
asia
# Out:
#       iso_code continent     location       date  total_cases  new_cases  \
# 212        AFG      Asia  Afghanistan 2019-12-31          0.0        0.0
# 213        AFG      Asia  Afghanistan 2020-01-01          0.0        0.0
# 214        AFG      Asia  Afghanistan 2020-01-02          0.0        0.0
# 215        AFG      Asia  Afghanistan 2020-01-03          0.0        0.0
# 216        AFG      Asia  Afghanistan 2020-01-04          0.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 49044      YEM      Asia        Yemen 2020-10-11       2055.0        1.0
# 49045      YEM      Asia        Yemen 2020-10-12       2055.0        0.0
# 49046      YEM      Asia        Yemen 2020-10-13       2056.0        1.0
# 49047      YEM      Asia        Yemen 2020-10-14       2056.0        0.0
# 49048      YEM      Asia        Yemen 2020-10-15       2057.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
len(asia)
# Out:
# 11982

# %%
asia.columns.to_list()
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'new_tests',
#  'total_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'tests_per_case',
#  'positive_rate',
#  'tests_units',
#  'stringency_index',
#  'population',
#  'population_density',
#  'median_age',
#  'aged_65_older',
#  'aged_70_older',
#  'gdp_per_capita',
#  'extreme_poverty',
#  'cardiovasc_death_rate',
#  'diabetes_prevalence',
#  'female_smokers',
#  'male_smokers',
#  'handwashing_facilities',
#  'hospital_beds_per_thousand',
#  'life_expectancy',
#  'human_development_index']

# %%
asia.isnull().sum()  #checking the null values for asia continent
# Out:
# iso_code                              0
# continent                             0
# location                              0
# date                                  0
# total_cases                         194
# new_cases                           194
# new_cases_smoothed                  305
# total_deaths                        194
# new_deaths                          194
# new_deaths_smoothed                 305
# total_cases_per_million             194
# new_cases_per_million               194
# new_cases_smoothed_per_million      305
# total_deaths_per_million            194
# new_deaths_per_million              194
# new_deaths_smoothed_per_million     305
# new_tests                          7194
# total_tests                        7004
# total_tests_per_thousand           7004
# new_tests_per_thousand             7194
# new_tests_smoothed                 6373
# new_tests_smoothed_per_thousand    6373
# tests_per_case                     6546
# ...

# %%
asia_col = ['location', 'date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'population','median_age','life_expectancy','cardiovasc_death_rate']

# %%
asia = asia[asia_col]

# %%
asia.head()
# Out:
#         location       date  total_cases  new_cases  total_deaths  new_deaths  \
# 212  Afghanistan 2019-12-31          0.0        0.0           0.0         0.0
# 213  Afghanistan 2020-01-01          0.0        0.0           0.0         0.0
# 214  Afghanistan 2020-01-02          0.0        0.0           0.0         0.0
# 215  Afghanistan 2020-01-03          0.0        0.0           0.0         0.0
# 216  Afghanistan 2020-01-04          0.0        0.0           0.0         0.0
#
#      population  median_age  life_expectancy  cardiovasc_death_rate
# 212  38928341.0        18.6            64.83                597.029
# 213  38928341.0        18.6            64.83                597.029
# 214  38928341.0        18.6            64.83                597.029
# 215  38928341.0        18.6            64.83                597.029
# 216  38928341.0        18.6            64.83                597.029

# %%
asia['location'].nunique()
# Out:
# 47

# %%
asia.shape
# Out:
# (11982, 10)

# %%
nepal = asia[asia['location'] == "Nepal"]

# %%
#Seeing the latest news of Covid in Nepal
nepal.tail()
# Out:
#       location       date  total_cases  new_cases  total_deaths  new_deaths  \
# 35167    Nepal 2020-10-11     105684.0     5008.0         614.0        14.0
# 35168    Nepal 2020-10-12     107755.0     2071.0         636.0        22.0
# 35169    Nepal 2020-10-13     111802.0     4047.0         645.0         9.0
# 35170    Nepal 2020-10-14     115358.0     3556.0         663.0        18.0
# 35171    Nepal 2020-10-15     117996.0     2638.0         675.0        12.0
#
#        population  median_age  life_expectancy  cardiovasc_death_rate
# 35167  29136808.0        25.0            70.78                260.797
# 35168  29136808.0        25.0            70.78                260.797
# 35169  29136808.0        25.0            70.78                260.797
# 35170  29136808.0        25.0            70.78                260.797
# 35171  29136808.0        25.0            70.78                260.797

# %% [markdown]
# ### As seen above, There are total cases of 117996 till now and death count is 675 in Nepal

# %%
plt.figure(figsize=(10,10))
plt.plot(nepal['date'], nepal['total_cases'], c='red')
plt.xlabel("Date")
plt.ylabel("Total Cases")
# Out:
# Text(0, 0.5, 'Total Cases')

# %% [markdown]
# ### Cases are increasing exponentially

# %% [markdown]
# -----

# %% [markdown]
# #### Lets see cases for the whole continent

# %%
plt.plot(asia['date'], asia['total_cases'], c='green')

# %%
asia.tail()
# Out:
#       location       date  total_cases  new_cases  total_deaths  new_deaths  \
# 49044    Yemen 2020-10-11       2055.0        1.0         595.0         1.0
# 49045    Yemen 2020-10-12       2055.0        0.0         596.0         1.0
# 49046    Yemen 2020-10-13       2056.0        1.0         596.0         0.0
# 49047    Yemen 2020-10-14       2056.0        0.0         597.0         1.0
# 49048    Yemen 2020-10-15       2057.0        1.0         597.0         0.0
#
#        population  median_age  life_expectancy  cardiovasc_death_rate
# 49044  29825968.0        20.3            66.12                495.003
# 49045  29825968.0        20.3            66.12                495.003
# 49046  29825968.0        20.3            66.12                495.003
# 49047  29825968.0        20.3            66.12                495.003
# 49048  29825968.0        20.3            66.12                495.003

# %%
#Finding the largest cases for different countries till now
asia.groupby(['location'])['total_cases'].max()
# Out:
# location
# Afghanistan               40026.0
# Armenia                   58624.0
# Azerbaijan                42750.0
# Bahrain                   76621.0
# Bangladesh               382959.0
# Bhutan                      316.0
# Brunei                      147.0
# Cambodia                    283.0
# China                     90869.0
# Georgia                   13521.0
# Hong Kong                     NaN
# India                   7307097.0
# Indonesia                344749.0
# Iran                     513219.0
# Iraq                     413215.0
# Israel                   299253.0
# Japan                     90710.0
# Jordan                    30550.0
# Kazakhstan               144328.0
# Kuwait                   113269.0
# Kyrgyzstan                50589.0
# Laos                         23.0
# Lebanon                   57246.0
# Malaysia                  17540.0
# Maldives                  11062.0
# Mongolia                    320.0
# Myanmar                   31325.0
# ...

# %%
asia[asia['location'] == 'Hong Kong']
# Out:
#         location       date  total_cases  new_cases  total_deaths  new_deaths  \
# 19969  Hong Kong 2020-01-31          NaN        NaN           NaN         NaN
# 19970  Hong Kong 2020-02-29          NaN        NaN           NaN         NaN
# 19971  Hong Kong 2020-03-31          NaN        NaN           NaN         NaN
# 19972  Hong Kong 2020-04-30          NaN        NaN           NaN         NaN
# 19973  Hong Kong 2020-05-31          NaN        NaN           NaN         NaN
# 19974  Hong Kong 2020-06-30          NaN        NaN           NaN         NaN
# 19975  Hong Kong 2020-07-31          NaN        NaN           NaN         NaN
# 19976  Hong Kong 2020-08-31          NaN        NaN           NaN         NaN
# 19977  Hong Kong 2020-09-01          NaN        NaN           NaN         NaN
# 19978  Hong Kong 2020-09-02          NaN        NaN           NaN         NaN
# 19979  Hong Kong 2020-09-03          NaN        NaN           NaN         NaN
# ...

# %%
#Dropping th Hong Kong row since it contains mostly NaN values
asia.drop(asia[asia['location'] == 'Hong Kong'].index.to_list(),inplace=True)

# %%
asia[asia['location'] == 'Hong Kong']
# Out:
# Empty DataFrame
# Columns: [location, date, total_cases, new_cases, total_deaths, new_deaths, population, median_age, life_expectancy, cardiovasc_death_rate]
# Index: []

# %%
asia.groupby(['location'])['total_cases'].max()  #Max cases till now
# Out:
# location
# Afghanistan               40026.0
# Armenia                   58624.0
# Azerbaijan                42750.0
# Bahrain                   76621.0
# Bangladesh               382959.0
# Bhutan                      316.0
# Brunei                      147.0
# Cambodia                    283.0
# China                     90869.0
# Georgia                   13521.0
# India                   7307097.0
# Indonesia                344749.0
# Iran                     513219.0
# Iraq                     413215.0
# Israel                   299253.0
# Japan                     90710.0
# Jordan                    30550.0
# Kazakhstan               144328.0
# Kuwait                   113269.0
# Kyrgyzstan                50589.0
# Laos                         23.0
# Lebanon                   57246.0
# Malaysia                  17540.0
# Maldives                  11062.0
# Mongolia                    320.0
# Myanmar                   31325.0
# Nepal                    117996.0
# ...

# %%
asia.isnull().sum()
# Out:
# location                   0
# date                       0
# total_cases              150
# new_cases                150
# total_deaths             150
# new_deaths               150
# population                 0
# median_age                 0
# life_expectancy            0
# cardiovasc_death_rate      0
# dtype: int64

# %%
len(nepal)
# Out:
# 290

# %%
#For India
india = asia[asia['location'] == "India"]

# %%
len(india)
# Out:
# 290

# %%
asia['location'].nunique()
# Out:
# 46

# %%
len(data)
# Out:
# 50301

# %%
asia[asia['location'] == "Yemen"]
# Out:
#       location       date  total_cases  new_cases  total_deaths  new_deaths  \
# 48860    Yemen 2020-04-10          1.0        1.0           0.0         0.0
# 48861    Yemen 2020-04-11          1.0        0.0           0.0         0.0
# 48862    Yemen 2020-04-12          1.0        0.0           0.0         0.0
# 48863    Yemen 2020-04-13          1.0        0.0           0.0         0.0
# 48864    Yemen 2020-04-14          1.0        0.0           0.0         0.0
# ...        ...        ...          ...        ...           ...         ...
# 49044    Yemen 2020-10-11       2055.0        1.0         595.0         1.0
# 49045    Yemen 2020-10-12       2055.0        0.0         596.0         1.0
# 49046    Yemen 2020-10-13       2056.0        1.0         596.0         0.0
# 49047    Yemen 2020-10-14       2056.0        0.0         597.0         1.0
# 49048    Yemen 2020-10-15       2057.0        1.0         597.0         0.0
#
# ...

# %%
X = nepal['new_cases']
y = nepal['new_deaths']

# %%
X
# Out:
# 34882       0.0
# 34883       0.0
# 34884       0.0
# 34885       0.0
# 34886       0.0
#           ...
# 35167    5008.0
# 35168    2071.0
# 35169    4047.0
# 35170    3556.0
# 35171    2638.0
# Name: new_cases, Length: 290, dtype: float64

# %%
y
# Out:
# 34882     0.0
# 34883     0.0
# 34884     0.0
# 34885     0.0
# 34886     0.0
#          ...
# 35167    14.0
# 35168    22.0
# 35169     9.0
# 35170    18.0
# 35171    12.0
# Name: new_deaths, Length: 290, dtype: float64

# %%
X.isnull().sum()
# Out:
# 13

# %%
len(X)
# Out:
# 290

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=0)

# %%
X_train
# Out:
# 35168    2071.0
# 35087     150.0
# 35109     525.0
# 34958       NaN
# 35017       2.0
#           ...
# 35133     980.0
# 35074     108.0
# 34999       0.0
# 34929       0.0
# 35054     426.0
# Name: new_cases, Length: 217, dtype: float64

# %%
X_train = X_train.fillna(X_train.mean())

# %%
X_train.isnull().sum()
# Out:
# 0

# %%
y_train.isnull().sum()
# Out:
# 9

# %%
y_train = y_train.fillna(y_train.mean())

# %%
X_test.isnull().sum()
# Out:
# 4

# %%
X_test = X_test.fillna(X_test.mean())

# %%
y_test = y_test.fillna(y_test.mean())

# %%
plt.scatter(X_train, y_train, c='green')

# %%
sns.boxplot(X_train)
# Out:
# <AxesSubplot:xlabel='new_cases'>

# %%
new_data = pd.concat([X_train, y_train], axis=1)

# %%
new_data
# Out:
#          new_cases  new_deaths
# 35168  2071.000000   22.000000
# 35087   150.000000    2.000000
# 35109   525.000000    4.000000
# 34958   404.057692    2.307692
# 35017     2.000000    0.000000
# ...            ...         ...
# 35133   980.000000    9.000000
# 35074   108.000000    0.000000
# 34999     0.000000    0.000000
# 34929     0.000000    0.000000
# 35054   426.000000    0.000000
#
# [217 rows x 2 columns]

# %%
new_data[new_data['new_cases']>4000].index.to_list()
# Out:
# [35169, 35167]

# %%
#Removing outliers
new_data.drop(new_data[new_data['new_cases']>4000].index.to_list(), inplace=True)

# %%
new_data[new_data['new_cases']>4000]
# Out:
# Empty DataFrame
# Columns: [new_cases, new_deaths]
# Index: []

# %%
new_data[(new_data['new_cases']>1000) & (new_data['new_deaths']==0)].index.to_list()
# Out:
# [35059]

# %%
#Removing outliers
new_data.drop(new_data[(new_data['new_cases']>1000) & (new_data['new_deaths']==0)].index.to_list(), inplace=True)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
X_train = np.array(X_train).reshape(-1,1)
y_train = np.array(y_train).reshape(-1,1)
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test = np.array(X_test).reshape(-1,1)
y_test = np.array(y_test).reshape(-1,1)

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([[ 0.42008567],
#        [ 0.42008567],
#        [ 5.17112985],
#        [ 1.06944176],
#        [ 6.05873889],
#        [ 0.42008567],
#        [ 7.48825661],
#        [ 1.40112724],
#        [ 0.42008567],
#        [ 0.42008567],
#        [ 0.42008567],
#        [ 0.43410055],
#        [ 0.42008567],
#        [ 6.76882612],
#        [ 2.71879674],
#        [ 9.34756397],
#        [ 3.19503183],
#        [ 0.48081682],
#        [ 2.6437799 ],
#        [ 0.45278706],
#        [ 0.42008567],
#        [ 4.41432635],
#        [ 0.42008567],
#        [ 2.19997538],
#        [11.8188544 ],
#        [ 6.24093233],
#        [ 0.42008567],
#        [ 3.41459828],
#        [ 1.02739712],
#        [ 2.19530375],
#        [ 0.4247573 ],
#        [ 0.42008567],
#        [ 0.42008567],
#        [ 1.70011134],
#        [ 2.58772038],
#        [ 5.65230738],
#        [ 1.69543972],
#        [ 4.6338928 ],
#        [ 0.42008567],
#        [ 2.71879674],
#        [ 2.71879674],
# ...

# %%
from sklearn.metrics import r2_score, classification_report, confusion_matrix
r2_score(y_test, y_pred)
# Out:
# 0.7172162854529917
